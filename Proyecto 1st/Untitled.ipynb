# %%
#!/usr/bin/python
from flask import Flask
from flask_restplus import Api, Resource, fields
from sklearn.externals import joblib
from Model_PriceCars import predict_car_value

app = Flask(__name__)

api = Api(
    app, 
    version='1.0', 
    title='Estimador de precio vehicular',
    description='Desarrollado por: Iván Gómez, Cristian Najera, Natalia Martinez')

ns = api.namespace('Predict', 
     description='Predict price')
   
parser = api.parser()

parser.add_argument(
    'Make', 
    type=str, 
    required=True, 
    help='Car Maker', 
    location='args')

parser.add_argument(
    'Model', 
    type=str, 
    required=True, 
    help='Car Model', 
    location='args')

parser.add_argument(
    'State', 
    type=str, 
    required=True, 
    help='State', 
    location='args')

parser.add_argument(
    'Mileage', 
    type=str, 
    required=True, 
    help='Mileage', 
    location='args')

parser.add_argument(
    'Year', 
    type=str, 
    required=True, 
    help='Year', 
    location='args')


resource_fields = api.model('Resource', {
    'result': fields.String,
})

@ns.route('/')
class PredPriceApi(Resource):

    @api.doc(parser=parser)
    @api.marshal_with(resource_fields)
    def get(self):
        args = parser.parse_args()
        
        return {
         "result": predict_car_value(args['Make'],args['Model'],args['State'],args['Mileage'],args['Year'])
        }, 200
    
    
if __name__ == '__main__':
    app.run(debug=True, use_reloader=False, host='0.0.0.0', port=8889)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://0.0.0.0:8889/ (Press CTRL+C to quit)
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:18:31] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=23388&Year=2015 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:18:42] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=23388&Year=2015 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:18:47] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=23388&Year=2013 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:18:55] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=23388&Year=2010 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:19:01] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=23388&Year=2020 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:19:09] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=123388&Year=2020 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:19:15] "GET /Predict/?Make=Ford&Model=EscapeFWD&State=OH&Mileage=123388&Year=2020 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:20:10] "GET /Predict/?Make=Toyota&Model=EscapeFWD&State=OH&Mileage=123388&Year=2020 HTTP/1.1" 200 -
# C:\Users\ivandario.gomez\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [07/Mar/2019 11:21:23] "GET /Predict/?Make=Toyota&Model=Camry4dr&State=OH&Mileage=123388&Year=2020 HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2019 11:21:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Mar/2019 11:21:29] "GET /swaggerui/droid-sans.css HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Mar/2019 11:21:29] "GET /swaggerui/swagger-ui.css HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Mar/2019 11:21:29] "GET /swaggerui/swagger-ui-standalone-preset.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Mar/2019 11:21:29] "GET /swaggerui/swagger-ui-bundle.js HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Mar/2019 11:21:30] "GET /swagger.json HTTP/1.1" 200 -
